# %%
import pandas as pd

# %%
mobnetv2 = pd.read_csv('res_mobnetv2.csv')

# %%
mobnetv2
# Out:
#         acc   val_acc      loss  val_loss  epoch
# 0  0.011533  0.019595  8.693822  8.385377      0
# 1  0.026886  0.024532  8.115376  8.379798      1
# 2  0.033340  0.026488  7.962585  8.453864      2

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
mobnetv2.plot(x='epoch', y= ['acc', 'val_acc', 'loss', 'val_loss'], 
              kind='line', subplots=[('acc', 'val_acc'), ('loss', 'val_loss')],
             layout=(1,2), figsize=(15,7),
             title='Plot of MobileNet V2 training');

# %%
ax1 = mobnetv2.plot(x='epoch', y=['acc', 'val_acc'], kind='line');

mobnetv2.plot(x='epoch', y=['loss', 'val_loss'], kind='line', ax=ax1);
